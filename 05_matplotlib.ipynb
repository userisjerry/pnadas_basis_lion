# %% [markdown]
# # 데이터 시각화
# - 데이터 시각화는 복잡하고 방대한 양의 데이터를 시각적인 요소를 활용하여 쉽고 빠르게 이해할 수 있도록 표현하는 과정
# - 다양한 시각적 도구를 사용하여 데이터의 특징, 추세, 패턴을 한눈에 파악

# %% [markdown]
# ![20240822_112716.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 데이터 시각화를 하는 이유
# - 복잡한 데이터를 간단하게
#     - 숫자로만 구성된 데이터는 이해하기 어렵지만, 시각적으로 표현하면 누구나 쉽게 파악
# - 데이터 간의 관계 파악
#     - 시각화를 통해 데이터 간의 관계를 직관적으로 확인
# - 숨겨진 정보 발견
#     - 숫자로만 분석하기 어려운 데이터 속에 숨겨진 패턴이나 이상치를 발견
# - 효과적인 의사소통
#     - 데이터를 시각화하면 복잡한 분석 결과를 간결하게 전달하고, 다른 사람들과 쉽게 공유

# %% [markdown]
# ## 데이터 시각화의 활용 분야
# - 비즈니스
#     - 매출 분석, 고객 행동 분석, 마케팅 전략 수립 등
# - 과학
#     - 연구 결과 시각화, 데이터 분석
# - 금융
#     - 주식 시장 분석, 투자 포트폴리오 관리
# - 의료
#     - 환자 데이터 분석, 질병 진단
# - 사회과학
#     - 사회 현상 분석, 설문 조사 결과 시각화

# %% [markdown]
# ## 데이터 시각화 도구
# - Tableau
#     - 데이터를 탐색하고 시각화하는 데 특화된 도구
# - Python (Matplotlib, Seaborn)
#     - 프로그래밍 방식으로 정교한 시각화를 구현
# - 엑셀
#     - 간단한 차트와 그래프를 생성하는 데 사용
# - 파워 BI
#     - 다양한 시각화 기능을 제공하며, 대규모 데이터 분석에 적합

# %% [markdown]
# # Matplotlib
# - 파이썬 데이터 시각화의 기본 도구
# - 파이썬에서 가장 널리 사용되는 데이터 시각화 라이브러리 중 하나
# - 간단한 선 그래프부터 복잡한 맞춤형 시각화까지 다양한 형태의 그래프를 생성
#
#
#
#
# - 설치
# ```bash
# pip install matplotlib
# ```

# %% [markdown]
# ## Matplotlib의 주요 특징
# - 선 그래프, 막대 그래프, 산점도, 히스토그램, 파이 차트 등 다양한 종류의 플롯을 지원
# - 플롯의 색상, 선 스타일, 마커, 레이블, 제목 등을 자유롭게 변경하여 원하는 시각화를 만들수 있음
# - Jupyter Notebook 환경에서 바로 시각화 결과를 확인 가능

# %% [markdown]
# ## Matplotlib의 장단점
# - 장점
#     - 유연성
#     > 다양한 차트 종류와 커스터마이징 옵션을 제공하여 복잡한 시각화도 구현 가능
#     - 확장성
#     > 다른 라이브러리와의 연동이 용이하여 다양한 방식으로 활용
#     - 오픈 소스
#     > 무료로 사용할 수 있으며, 활발한 커뮤니티를 통해 많은 정보를 얻을 수 있음
# - 단점
#     - 복잡성
#     > 기본적인 사용법은 간단하지만, 복잡한 시각화를 하려면 많은 코드를 작성해야 함
#     - 학습 곡선
#     > 다양한 기능을 익히는 데 시간이 걸릴 수 있음

# %% [markdown]
# ## 언제 Matplotlib을 사용해야 할까?
# - 간단한 시각화
#     - 선 그래프, 막대 그래프 등 기본적인 시각화가 필요할 때
# - 맞춤형 시각화
#     - 다른 시각화 라이브러리로는 구현하기 어려운 복잡한 시각화가 필요할 때
# - 다른 라이브러리와의 연동
#     - 다른 시각화 라이브러리와 함께 사용하여 더욱 강력한 시각화를 구현하고 싶을 때

# %% [markdown]
# ## matplotlib 이용할때 한글 깨짐 현상 해결방법

# %% [markdown]
# ```python
# # 윈도우 pc 에서의 방법
# import matplotlib.pyplot as plt
# plt.rcParams['font.family'] ='Malgun Gothic' # AppleGothic
# plt.rcParams['axes.unicode_minus'] =False
#
# # 코랩에서의 방법
# import matplotlib
# from matplotlib import font_manager
#
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
#
# fontpaths = ["/usr/share/fonts/truetype/nanum/"]
# font_files = font_manager.findSystemFonts(fontpaths=fontpaths)
#
# for ff in font_files:
#     font_manager.fontManager.addfont(ff)
#
# matplotlib.rc('font', family="NanumGothic")
# matplotlib.rcParams['axes.unicode_minus'] = False
# ```

# %%
import matplotlib
from matplotlib import font_manager

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv

fontpaths = ["/usr/share/fonts/truetype/nanum/"]
font_files = font_manager.findSystemFonts(fontpaths=fontpaths)

for ff in font_files:
    font_manager.fontManager.addfont(ff)

matplotlib.rc('font', family="NanumGothic")
matplotlib.rcParams['axes.unicode_minus'] = False
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (25.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %% [markdown]
# ## figure와 axes 객체
# - figure
#     - 전체 그림판
#     - Figure는 1개 이상의 그래프들을 담는 틀이나 창을 의미
#     - 우리가 최종적으로 보게 되는 시각화 그래프들의 전체를 감싸는 가장 바깥쪽 영역
# - axes
#     - Axes는 Figure 내부에 존재하는 하나의 그래프 그리는 공간
#     - 실제로 데이터를 시각화하여 그래프, 차트 등을 그리는 영역

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.axes()
plt.show()

# %% [markdown]
# ## 단일 그래프

# %% [markdown]
# - plot 함수
#     - line plot을 그려주는 함수

# %%
plt.plot( np.arange(2,7) )
plt.show()

# %% [markdown]
# ## 다중 그래프
# - 1개의 axes 안에 여러개의 그래프를 그린다.

# %%
plt.figure(figsize=[15,5])
plt.plot( np.arange(5) )
plt.plot( np.arange(2,7) )
plt.show()

# %% [markdown]
# ## subplots 함수를 이용해서 axes 여러 개 그리기

# %%
fig, ax = plt.subplots(2,2, figsize=[15,5])
ax[0,0].plot( np.arange(5) )
ax[0,0].plot( np.arange(2,7) )
ax[0,1].plot( np.arange(2,7) )
ax[1,0].plot( np.arange(2,7) )
ax[1,1].plot( np.arange(2,7) )
plt.show()

# %% [markdown]
# - 다른 방식

# %%
plt.figure(figsize=[15,5])

plt.subplot(2,2,1)
plt.plot(np.arange(5))

plt.subplot(2,2,2)
plt.plot(np.arange(5))
plt.plot(np.arange(2,7))

plt.subplot(2,2,3)
plt.plot(np.arange(5))

plt.subplot(2,2,4)
plt.plot(np.arange(5))

plt.show()

# %%
plt.figure(figsize=[15,5])

plt.subplot(221)
plt.plot(np.arange(5))

plt.subplot(222)
plt.plot(np.arange(5))
plt.plot(np.arange(2,7))

plt.subplot(223)
plt.plot(np.arange(5))

plt.subplot(224)
plt.plot(np.arange(5))

plt.show()

# %% [markdown]
# ## 타이틀 설정하기

# %%
fig , ax = plt.subplots(1,2, figsize=[15,5])
fig.suptitle("fig 제목")

x = np.arange(10)
ax[0].plot( x, np.exp(x) )
ax[0].set_title("ax1 제목")

x = np.arange(1,1000)
ax[1].plot( x, np.log(x) )
ax[1].set_title("ax2 제목")

plt.show()

# %%
x = np.arange(1,1000)
y = np.log(x)

# %% [markdown]
# ## x, y 축에 이름 넣기

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_xlabel("X축 이름") # rotation=90
ax.set_ylabel("Y축 이름", rotation=0, labelpad= 50)
plt.show()

# %% [markdown]
# ## 눈금 회전하기

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.tick_params(axis="x", rotation=90)
plt.show()

# %% [markdown]
# ## 눈금 지정하기

# %%
fig, ax = plt.subplots(figsize=[15,10])
ax.plot(np.arange(50))
ax.set_xticks(np.arange(50))
ax.set_yticks(np.arange(50))
# ax.tick_params(axis="x", rotation=90)
plt.show()

# %% [markdown]
# ## marker, line style, line color 변경하기

# %%
fig, ax = plt.subplots(2,2,figsize=[15,5])
ax[0,0].plot( np.exp( range(0,10) ) , marker = "o")
ax[0,1].plot( np.exp( range(0,10) ) , marker = "v", color="red", linestyle="--")
ax[1,0].plot( np.exp( range(0,10) ) , marker = "x", color="black", linestyle="")
ax[1,1].plot( np.exp( range(0,10) ) , marker = "^", color="#D1B2FF")
plt.show()

# %% [markdown]
# ## 범례표시하기

# %%
fig, ax = plt.subplots()

y = np.arange(10)
ax.plot(y)
ax.plot(y**2, alpha=0.2)
ax.legend( ["X", "X^2"], loc=[0.1,0.8] )

plt.show()

# %% [markdown]
# ## line plot
# * 일반적으로 시간을 x축에 두고 y축에 데이터의 추이를 볼때 사용
# * x값의 변화에 따른 y 값의 변화에 대한 흐름
# * 예시
#   - 특정 기간 동안의 주가 변동
#   - 기온, 강수량 변화
#   - 웹 사이트의 방문자수 추이
#   - 월별, 분기별, 연도별 매출액 변화

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
data_path = '/content/drive/MyDrive/data_lion'
df = pd.read_csv(f'{data_path}/campaign_train.csv')
df.head()
# Out:
#         ID  출생연도 고객_교육수준 고객_결혼여부    고객_소득  고객_자녀수  고객_청소년수     고객_가입날짜  \
# 0  train_0  1969      박사      기혼  30396.0       1        0  2014-04-30
# 1  train_1  1967      박사      기혼  36947.0       1        1  2012-08-07
# 2  train_2  1949      석사      사별  47570.0       1        1  2013-05-29
# 3  train_3  1976      석사      기혼  81929.0       1        0  2012-09-29
# 4  train_4  1982      고졸      기혼  57937.0       0        1  2014-02-16
#
#    고객_최신구매일_경과기간  고객_와인_구매금액  ...  고객_카탈로그_통한_구매횟수  고객_매장방문_구매횟수  \
# 0             22          15  ...                1             2
# 1             49          88  ...                0             4
# 2              3          67  ...                2             2
# 3             60        1486  ...                4            10
# 4             56         261  ...                4             9
#
#    고객_지난달_회사사이트_방문횟수  캠페인1_수락여부  캠페인2_수락여부  캠페인3_수락여부  캠페인4_수락여부  캠페인5_수락여부  \
# ...

# %%
df.columns
# Out:
# Index(['ID', '출생연도', '고객_교육수준', '고객_결혼여부', '고객_소득', '고객_자녀수', '고객_청소년수',
#        '고객_가입날짜', '고객_최신구매일_경과기간', '고객_와인_구매금액', '고객_과일_구매금액', '고객_육류_구매금액',
#        '고객_생선_구매금액', '고객_사탕_구매금액', '고객_골드_구매금액', '고객_할인품목_구매횟수',
#        '고객_회사사이트_통한_구매횟수', '고객_카탈로그_통한_구매횟수', '고객_매장방문_구매횟수',
#        '고객_지난달_회사사이트_방문횟수', '캠페인1_수락여부', '캠페인2_수락여부', '캠페인3_수락여부', '캠페인4_수락여부',
#        '캠페인5_수락여부', '불만제기', 'target'],
#       dtype='object')

# %%
# 연도 월별 가입자 추
tmp = df['고객_가입날짜'].str[:7].value_counts().reset_index().sort_values('고객_가입날짜')
tmp
# Out:
#     고객_가입날짜  count
# 23  2012-07      1
# 0   2012-08     75
# 7   2012-09     61
# 17  2012-10     55
# 6   2012-11     63
# 13  2012-12     57
# 2   2013-01     65
# 9   2013-02     60
# 8   2013-03     61
# 14  2013-04     56
# 5   2013-05     63
# 16  2013-06     55
# 15  2013-07     55
# 10  2013-08     59
# 12  2013-09     58
# 4   2013-10     64
# 20  2013-11     49
# 18  2013-12     54
# 19  2014-01     54
# 21  2014-02     47
# 1   2014-03     66
# 11  2014-04     59
# 3   2014-05     65
# 22  2014-06     42

# %%
fig, ax = plt.subplots()
ax.plot(tmp['고객_가입날짜'], tmp['count'])
ax.tick_params(axis="x", rotation=90)
plt.show()

# %%
df.columns
# Out:
# Index(['ID', '출생연도', '고객_교육수준', '고객_결혼여부', '고객_소득', '고객_자녀수', '고객_청소년수',
#        '고객_가입날짜', '고객_최신구매일_경과기간', '고객_와인_구매금액', '고객_과일_구매금액', '고객_육류_구매금액',
#        '고객_생선_구매금액', '고객_사탕_구매금액', '고객_골드_구매금액', '고객_할인품목_구매횟수',
#        '고객_회사사이트_통한_구매횟수', '고객_카탈로그_통한_구매횟수', '고객_매장방문_구매횟수',
#        '고객_지난달_회사사이트_방문횟수', '캠페인1_수락여부', '캠페인2_수락여부', '캠페인3_수락여부', '캠페인4_수락여부',
#        '캠페인5_수락여부', '불만제기', 'target'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# 연도별 고객_와인_구매금액의 매출 추이를 그려주세요

# %%
df['가입_연도'] = df['고객_가입날짜'].str[:4]

annual_sales = df.groupby('가입_연도')['고객_와인_구매금액'].sum().reset_index()

plt.figure(figsize=(10, 6))
plt.bar(annual_sales['가입_연도'], annual_sales['고객_와인_구매금액'], color='skyblue')
plt.grid(True)
plt.show()

# %%
tmp = df.groupby('가입_연도')['고객_와인_구매금액'].sum()
# 결과는 시리즈
tmp = tmp.reset_index()

# %%
fig, ax = plt.subplots()
ax.plot(tmp['가입_연도'], tmp['고객_와인_구매금액'])
plt.show()

# %% [markdown]
# # scatter plot
# * 산점도
# * 두수치형 변수 사이의 관계를 시각화
#    - 키와 몸무게의 관계, 나이와 혈압의 관계
#    - 소비와 지출의 관계, 주가와 이자율의 관계

# %%
df.columns
# Out:
# Index(['ID', '출생연도', '고객_교육수준', '고객_결혼여부', '고객_소득', '고객_자녀수', '고객_청소년수',
#        '고객_가입날짜', '고객_최신구매일_경과기간', '고객_와인_구매금액', '고객_과일_구매금액', '고객_육류_구매금액',
#        '고객_생선_구매금액', '고객_사탕_구매금액', '고객_골드_구매금액', '고객_할인품목_구매횟수',
#        '고객_회사사이트_통한_구매횟수', '고객_카탈로그_통한_구매횟수', '고객_매장방문_구매횟수',
#        '고객_지난달_회사사이트_방문횟수', '캠페인1_수락여부', '캠페인2_수락여부', '캠페인3_수락여부', '캠페인4_수락여부',
#        '캠페인5_수락여부', '불만제기', 'target', '가입_연도'],
#       dtype='object')

# %%
# 육류 구매금액이 늘어날수록, 와인 구매 금액이 늘어나는지 -> 수치형 관계
# 산점도로 표현
fig, ax = plt.subplots()
ax.scatter(df['고객_와인_구매금액'], df['고객_육류_구매금액'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots()
ax.scatter(df['고객_와인_구매금액'], df['고객_육류_구매금액'],s=df['고객_골드_구매금액'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 색으로는 c
fig, ax = plt.subplots()
ax_obj = ax.scatter(df['고객_와인_구매금액'], df['고객_육류_구매금액'],c=df['고객_과일_구매금액'])
plt.colorbar(ax_obj)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['고객_와인_구매금액'].corr(df['고객_육류_구매금액'])
# Out:
# 0.5510796458573771

# %% [markdown]
# # bar 차트
# * 범주형 변수에 대한 집계를 시각화
# * 범주의 빈도수를 비교할 때 사용
# * 예시
#   - 연령대별 인구수, 지역별 인구수
#   - 상품별 구매 빈도
#   - 과목별 평균 점수를 비교
#   -

# %%
# 고객 교육수준 별로/ 가입자 수를 막대그래프로
tmp = df['고객_교육수준'].value_counts()
# 고객 교육수준ㅇ르 x 축으로
# count를 y 축으로
tmp
# 시리즈
# Out:
# 고객_교육수준
# 학사       647
# 박사       306
# 석사       224
# 고졸       119
# 초졸_중졸     35
# Name: count, dtype: int64

# %%
fig, ax= plt.subplots()
ax.bar(tmp.index, tmp)
plt.show()

# %%
fig, ax= plt.subplots()
ax.bar(tmp.index, tmp)
ax.tick_params(axis="x", rotation=90)
plt.show()

# %%
# 2013년도 부터 가입한 고객들에 대하여
# 고객_교육수준별 / 고객_매장방문_구매횟수 / 합ㅇ르 바플랏으로 시각화
df.columns
# Out:
# Index(['ID', '출생연도', '고객_교육수준', '고객_결혼여부', '고객_소득', '고객_자녀수', '고객_청소년수',
#        '고객_가입날짜', '고객_최신구매일_경과기간', '고객_와인_구매금액', '고객_과일_구매금액', '고객_육류_구매금액',
#        '고객_생선_구매금액', '고객_사탕_구매금액', '고객_골드_구매금액', '고객_할인품목_구매횟수',
#        '고객_회사사이트_통한_구매횟수', '고객_카탈로그_통한_구매횟수', '고객_매장방문_구매횟수',
#        '고객_지난달_회사사이트_방문횟수', '캠페인1_수락여부', '캠페인2_수락여부', '캠페인3_수락여부', '캠페인4_수락여부',
#        '캠페인5_수락여부', '불만제기', 'target', '가입_연도'],
#       dtype='object')

# %%
df['가입_연도'] = df['고객_가입날짜'].str[:4].astype(int)
abc = df[df['가입_연도'] >= 2013]
# Out:
# <ipython-input-82-5ea44a48de24>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['가입_연도'] = df['고객_가입날짜'].str[:4].astype(int)

# %%
tmp = abc.groupby('고객_교육수준')['고객_매장방문_구매횟수'].sum().reset_index()
fig, ax= plt.subplots()
ax.bar(tmp['고객_교육수준'], tmp['고객_매장방문_구매횟수'])
ax_params={
    'x' : tmp['고객_교육수준'],
    'height' : tmp['고객_매장방문_구매횟수'],
    'color' : ['skyblue', 'red','orange','yellow','green']

}

ax.bar(**ax_params)
plt.show()

# %% [markdown]
# # pie 차트
# * 원 그래프를 전체에서 각 범주들의 부분을 비율로 표현한 그래프
# * 전체를 구성하는 부분들의 비율을 한 눈에 보여주는데 효과적인 차트

# %%
tmp
# Out:
#   고객_교육수준  고객_매장방문_구매횟수
# 0      고졸           453
# 1      박사          1301
# 2      석사          1056
# 3   초졸_중졸            65
# 4      학사          2871

# %%
fig, ax  = plt.subplots()

ax.pie(
    tmp['고객_매장방문_구매횟수'],
    labels=tmp['고객_교육수준'],
    autopct='%.2f%%'
)
plt.show()

# %%
fig, ax  = plt.subplots()

ax.pie(
    tmp['고객_매장방문_구매횟수'],
    labels=tmp['고객_교육수준'],
    autopct='%.2f%%',
    startangle=90,
    explode=[0.1,0.1,0.1,0.4,0] # 삐져나옴
)
plt.show()

# %% [markdown]
# # histogram
# * 수치형 데이터의 구간의 빈도 수를 볼 때 사용
# * 수치형 데이터의 분포를 확인할 때 사용
# * 예시
#   - 시험 점수 분포
#   - 소득 분포

# %%
# 평균이 0, 분산1, 정규분포의 랜던값 반환
np.random.seed(42)
arr = np.random.rand(1000)
fig,ax = plt.subplots()
ax.hist(arr)
plt.show()

# %%
fig,ax = plt.subplots()
ax.hist(df['고객_와인_구매금액'])
plt.show()

# %%
fig,ax = plt.subplots()
ax.hist(df['고객_매장방문_구매횟수'])
plt.show()

# %%
df.columns
# Out:
# Index(['ID', '출생연도', '고객_교육수준', '고객_결혼여부', '고객_소득', '고객_자녀수', '고객_청소년수',
#        '고객_가입날짜', '고객_최신구매일_경과기간', '고객_와인_구매금액', '고객_과일_구매금액', '고객_육류_구매금액',
#        '고객_생선_구매금액', '고객_사탕_구매금액', '고객_골드_구매금액', '고객_할인품목_구매횟수',
#        '고객_회사사이트_통한_구매횟수', '고객_카탈로그_통한_구매횟수', '고객_매장방문_구매횟수',
#        '고객_지난달_회사사이트_방문횟수', '캠페인1_수락여부', '캠페인2_수락여부', '캠페인3_수락여부', '캠페인4_수락여부',
#        '캠페인5_수락여부', '불만제기', 'target', '가입_연도'],
#       dtype='object')

# %% [markdown]
# # Box Plot
# - 4분위수를 기준으로 데이터의 최대, 최소, Q1(25%지점), Q2(50%지점), Q3(75%지점) 등 통계적인 부분들을 손쉽게 시각화
# - 이상치도 빠르게 판단이 가능
# - IQR(Inter Quantile Range) : 3Q - Q1 , 3사분위수와 1사분위수의 차이
# - Box Plot에서 최소값: Q1 - IQR * 1.5
# - Box Plot에서 최대값: Q3 + IQR * 1.5
# - Box Plot에서 최소값과 최대값을 벗어나면 이상치로 해석함

# %% [markdown]
# ![다운로드.gif](data:image/gif;base64,...)

# %%
fig, ax = plt.subplots()
ax.boxplot(df['고객_골드_구매금액'])
plt.show()

# %%
col_name = '고객_골드_구매금액'

df[col_name].quantile(np.arange(0, 1.1, 0.25)).to_numpy()
# Out:
# array([  0.,   7.,  21.,  50., 362.])

# %%
q= df[col_name].quantile(np.arange(0, 1.1, 0.25)).to_numpy()
q
# Out:
# array([  0.,   7.,  21.,  50., 362.])

# %%
iqr = q[3] - q[1]
box_min = q[1] - 1.5 * iqr # boxplot minimum
box_max = q[3] + 1.5 * iqr  # boxplot maximum

box_min, box_max
# Out:
# (-57.5, 114.5)

# %%
yticks=np.concatenate([
    q,
   [box_min,box_max]]

)
yticks
# Out:
# array([  0. ,   7. ,  21. ,  50. , 362. , -57.5, 114.5])

# %%
fig, ax = plt.subplots()
ax.boxplot(df[col_name], vert = False)
ax.set_yticks(yticks)
plt.show()
## vert = False : 옆으로

# %%
fig, ax = plt.subplots()
ax.boxplot(df[col_name])
ax.set_yticks(yticks)
plt.show()

# %% [markdown]
# # heatmap

# %%
corr_df = df.corr(numeric_only=True)
corr_df
# Out:
#                        출생연도     고객_소득    고객_자녀수   고객_청소년수  고객_최신구매일_경과기간  \
# 출생연도               1.000000 -0.137481  0.226878 -0.355484      -0.053158
# 고객_소득             -0.137481  1.000000 -0.388959  0.007900       0.002210
# 고객_자녀수             0.226878 -0.388959  1.000000 -0.043289      -0.024847
# 고객_청소년수           -0.355484  0.007900 -0.043289  1.000000       0.029077
# 고객_최신구매일_경과기간     -0.053158  0.002210 -0.024847  0.029077       1.000000
# 고객_와인_구매금액        -0.151917  0.487729 -0.501476 -0.003694       0.019425
# 고객_과일_구매금액        -0.015034  0.368474 -0.394878 -0.165086       0.004878
# 고객_육류_구매금액        -0.040589  0.485519 -0.448570 -0.264774       0.060363
# 고객_생선_구매금액        -0.047000  0.384223 -0.414619 -0.193532       0.005088
# 고객_사탕_구매금액        -0.018215  0.373239 -0.380195 -0.141000       0.018125
# 고객_골드_구매금액        -0.050024  0.279755 -0.359108 -0.015191       0.018619
# 고객_할인품목_구매횟수      -0.043511 -0.081657  0.208024  0.364298      -0.006376
# ...

# %%
cols = corr_df.columns.tolist() #index 대신 columns해도 된다
len(cols)
# Out:
# 24

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax_ob = ax.matshow(corr_df)
ax.set_xticks(np.arange(len(cols)),cols)
ax.set_yticks(np.arange(len(cols)),cols)
ax.tick_params(axis="x", rotation=90)
plt.colorbar(ax_ob)
plt.show()

# %%
df
# Out:
#               ID  출생연도 고객_교육수준 고객_결혼여부    고객_소득  고객_자녀수  고객_청소년수     고객_가입날짜  \
# 0        train_0  1969      박사      기혼  30396.0       1        0  2014-04-30
# 2        train_2  1949      석사      사별  47570.0       1        1  2013-05-29
# 4        train_4  1982      고졸      기혼  57937.0       0        1  2014-02-16
# 5        train_5  1969      학사      동거  21918.0       1        0  2013-11-14
# 6        train_6  1970      박사      기혼  67536.0       0        1  2013-05-22
# ...          ...   ...     ...     ...      ...     ...      ...         ...
# 1338  train_1338  1958      학사      동거  65196.0       0        2  2013-07-25
# 1340  train_1340  1976      학사      미혼  37697.0       1        0  2014-02-07
# 1341  train_1341  1967      학사      기혼  35441.0       1        1  2013-02-14
# 1342  train_1342  1983      학사      기혼  36790.0       0        0  2013-03-01
# 1343  train_1343  1981      학사      기혼  40211.0       1        1  2013-07-30
#
# ...

# %%
df.columns
# Out:
# Index(['ID', '출생연도', '고객_교육수준', '고객_결혼여부', '고객_소득', '고객_자녀수', '고객_청소년수',
#        '고객_가입날짜', '고객_최신구매일_경과기간', '고객_와인_구매금액', '고객_과일_구매금액', '고객_육류_구매금액',
#        '고객_생선_구매금액', '고객_사탕_구매금액', '고객_골드_구매금액', '고객_할인품목_구매횟수',
#        '고객_회사사이트_통한_구매횟수', '고객_카탈로그_통한_구매횟수', '고객_매장방문_구매횟수',
#        '고객_지난달_회사사이트_방문횟수', '캠페인1_수락여부', '캠페인2_수락여부', '캠페인3_수락여부', '캠페인4_수락여부',
#        '캠페인5_수락여부', '불만제기', 'target', '가입_연도'],
#       dtype='object')

# %%
# 각 고객_교육수준 에 대하여 /고객_결혼여부 별 /////  고객_와인_구매금액의 평균을 히트맵으로 시각화

# %%
asd = df.groupby(['고객_교육수준', '고객_결혼여부'])['고객_와인_구매금액'].mean().reset_index()

# %%
tmpp = pd.pivot_table(df ,index='고객_교육수준',
               columns='고객_결혼여부',
               values='고객_와인_구매금액',
               aggfunc = 'mean',
               # fill_value=0'
               )
## x,y 바꾸고 싶음면 tmpp.T

# %%
fig,ax= plt.subplots(figsize=(10,10))

ax_ob = ax.matshow(tmpp)

ax.set_xticks(np.arange(len(tmpp.columns)),tmpp.columns)

ax.set_yticks(np.arange(len(tmpp.index)),tmpp.index)
plt.colorbar(ax_ob)
plt.show()
